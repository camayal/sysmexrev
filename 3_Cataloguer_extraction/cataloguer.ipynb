# %%
import pandas as pd
import re 
import numpy as np
import urllib

# %%
# load list of titles as one column dataframe
df_raw = pd.read_csv("../Organizer_extraction/conserved_titles.txt", low_memory = True, delimiter="\t", names=["title"])

# %%
# list of markers for detec sanger, nuclear, and chloroplast info
nuclear_markers = "Internal transcribed spacer|ITS1|ITS2|ETS|nrITS|18S"
chl_markers = "trn[LGR]|atpB|rubisco|rbcL|psbA|trnH|matk|psbJ|petA"

# set catagories of search
categories = {
    #scope
    "Taxonomy": "taxonom|delimit|clas*ific|circumpscri|new species|nueva.? especie",
    "Systematic": "s[yi]stem.t| comple[xj]|phylog|filog|clade|speciation|monophy|monofi|rela[tc]ion|biogeo|evolu",
    # "Other related": "barcod| barra|h[yi]brid",
    "Mexico": "m*[xj]ico",
    #tematics
    "Morphology": "morpholog|morfolog",
    "First gen.": f"{nuclear_markers}|{chl_markers}| sanger | marker| nuclear region| chloroplast region|regi.n.*? nucr|regi.n.*? cloro",
    "Second gen.": "radseq|angiosperm353|hybseq|454|illumina|iontorrent",
    "Third gen.": "pacbio|nanopore",
    "Nuclear info": f"nuclear|{nuclear_markers}",
    "Chloroplast info": f"c.?lorop|{chl_markers}",
    "Parsimony": "parsimon",
    "Maximum likelihood": " ML |maximum likelihood|verosimilitud",
    "Bayesian": "bayes",
    "MSC": " astral | astrid | bpp |coalescent"
    ""
}

# %%
test = "A Molecular Phylogenetic Study of the Palmae (Arecaceae) Based on atpB, rbcL, and 18S nrDNA Sequences"
for k in categories:
    print(f"{k}: {re.search(categories[k], test, re.IGNORECASE)}")
# Out:
# Taxonomy: None
# Systematic: <re.Match object; span=(12, 18), match='Phylog'>
# Other related: None
# Mexico: None
# Morphology: None
# First gen.: <re.Match object; span=(66, 70), match='atpB'>
# Second gen.: None
# Third gen.: None
# Nuclear info: <re.Match object; span=(82, 85), match='18S'>
# Chloroplast info: <re.Match object; span=(66, 70), match='atpB'>
# Parsimony: None
# Maximum likelihood: None
# Bayesian: None
# MSC: None

# %%
# copy original df
df = df_raw.copy()

# create the main columns for the scope of this search and google link
df["REVISADO (bibtex citation)"] = np.nan
df["Google link"] = np.nan
df["Taxonomy"] = np.nan
df["Systematic"] = np.nan
# df["Other related"] = np.nan
df["Mexico"] = np.nan

# iterate row by row
for index, row in df.iterrows():
    # check every key in category dictionary 
    for k in categories:
        # create empty column
        # search every pattern in title
        if re.search(categories[k], row["title"], re.IGNORECASE):
           #add a helper link to go directly to google scholar
           searchquery = urllib.parse.urlencode({"q": row["title"]})
           df.loc[index, "Google link"] = f"https://scholar.google.com/scholar?&{searchquery}"
           #add Auto in the cell to indicate this part of the search is true
           df.loc[index, k] = "Auto"

# %%
df
# Out:
#                                                    title  \
# 0      'Andean-centred' genera in the short-branch cl...
# 1      'Le Rouge et le Noir': A decline in flavone fo...
# 2      'Mediterranean' disjunction in Senecio sect. S...
# 3      'Real time' genetic manipulation: a new tool f...
# 4      'What are natural clades in the Caesalpinia gr...
# ...                                                  ...
# 12163  trnL-F and rpl16 Sequence Data and Dense Taxon...
# 12164  ural Delineation, Molecular Phylogeny and Flor...
# 12165  ving relationships within Valerianaceae (Dipsa...
# 12166  xLindsaeosoria flynnii (Lindsaeaceae), Another...
# 12167  ycf1, the most promising plastid DNA barcode o...
#
#                                              Google link Taxonomy Systematic  \
# 0      https://scholar.google.com/scholar?&q=%27Andea...      NaN       Auto
# 1                                                    NaN      NaN        NaN
# 2      https://scholar.google.com/scholar?&q=%27Medit...      NaN       Auto
# 3                                                    NaN      NaN        NaN
# 4      https://scholar.google.com/scholar?&q=%27What+...      NaN       Auto
# ...                                                  ...      ...        ...
# 12163  https://scholar.google.com/scholar?&q=trnL-F+a...      NaN       Auto
# 12164  https://scholar.google.com/scholar?&q=ural+Del...      NaN       Auto
# 12165  https://scholar.google.com/scholar?&q=ving+rel...      NaN       Auto
# 12166  https://scholar.google.com/scholar?&q=xLindsae...      NaN        NaN
# 12167  https://scholar.google.com/scholar?&q=ycf1%2C+...      NaN        NaN
#
#       Other related Mexico First gen. Nuclear info Chloroplast info  \
# 0               NaN    NaN        NaN          NaN              NaN
# 1               NaN    NaN        NaN          NaN              NaN
# 2               NaN    NaN        NaN          NaN              NaN
# 3               NaN    NaN        NaN          NaN              NaN
# 4               NaN    NaN        NaN          NaN              NaN
# ...             ...    ...        ...          ...              ...
# 12163           NaN    NaN       Auto          NaN             Auto
# 12164           NaN    NaN        NaN          NaN              NaN
# 12165           NaN    NaN       Auto         Auto              NaN
# 12166          Auto    NaN        NaN          NaN              NaN
# 12167          Auto    NaN        NaN          NaN              NaN
#
#       Morphology Maximum likelihood Parsimony Third gen. Bayesian Second gen.  \
# 0            NaN                NaN       NaN        NaN      NaN         NaN
# 1            NaN                NaN       NaN        NaN      NaN         NaN
# 2            NaN                NaN       NaN        NaN      NaN         NaN
# 3            NaN                NaN       NaN        NaN      NaN         NaN
# 4            NaN                NaN       NaN        NaN      NaN         NaN
# ...          ...                ...       ...        ...      ...         ...
# 12163        NaN                NaN       NaN        NaN      NaN         NaN
# 12164        NaN                NaN       NaN        NaN      NaN         NaN
# 12165        NaN                NaN       NaN        NaN      NaN         NaN
# 12166        NaN                NaN       NaN        NaN      NaN         NaN
# 12167        NaN                NaN       NaN        NaN      NaN         NaN
#
#        MSC
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 12163  NaN
# 12164  NaN
# 12165  NaN
# 12166  NaN
# 12167  NaN
#
# [12168 rows x 16 columns]

# %%
# remove rows that has NaN for all categories (out of the scope of this study)
df_final = df[(df['Taxonomy'].notnull()) | (df['Systematic'].notnull()) | (df['Other related'].notnull()) | (df['Mexico'].notnull())]

# %%
df[(df['Mexico'].notnull()) & (df['Systematic'].isnull()) & (df['Taxonomy'].isnull())]
# Out:
#                                                    title  \
# 278    A historical landscape approach to assessing g...
# 780    Aberrant Plant Diversity in the Purgatory Wate...
# 781    Aberrant Plant Diversity in the Purgatory Wate...
# 1558   Characterization of 42 microsatellite markers ...
# 3169   Direct and indirect estimations of gene flow a...
# 3241   Distribution and morphological characteristics...
# 3319   Diversity of agaves used to produce pulque in ...
# 3635   Evolution and domestication of Lima bean (Phas...
# 3682   Evolution of Tidestromia (Amaranthaceae) in th...
# 3909   Expression Analysis of Genes Involved in the S...
# 4035   First Report of Arceuthobium hondurense in Mexico
# 4368   Genetic diversity and functionality of tropica...
# 4382   Genetic diversity of tropical tree local commu...
# 4383   Genetic diversity studies using beta-tubulin g...
# 4413   Genetic structure and diversity in shoalgrass ...
# 4425   Genetic variation and evolution of Polaskia ch...
# 4669   Historic Dynamics of Introgressive Hybridizati...
# 4901          Identification of Bacopa species in Mexico
# 5098   In Vitro Bioactivity of Methanolic Extracts fr...
# 5183   Infraspecific diversification of the star cloa...
# 6681   Molecular identification of seven species of t...
# 7143   Morphological and molecular identification of ...
# 7258            Native Quercus from Mexico and Guatemala
# 7761   Paneroa, a new genus of Eupatorieae (Asteracea...
# 9442   Pilostyles maya, a novel species and the first...
# 9468   Plant core DNA barcode performance at a local ...
# 9603   Pollination networks of nectarivorous bats in ...
# 9841   Quaternary origin and genetic divergence of th...
# 9972   Regional patterns of genetic structure and env...
# 10056  Report of Lippia graveolens Kunth s.l. in the ...
# 10365  Sequencing and de novo assembly of the Toxicod...
# 10455  Sotoa, a new genus of Spiranthinae (Orchidacea...
# 10838  Target and Non-target Site Mechanisms Develope...
# 11159  The complete genome sequence of Toxicodendron ...
# 11206  The ectomycorrhizas of Lactarius cuspidoaurant...
# 11855  Unraveling reticulate evolution in Opuntias fr...
# 12005  Wetland conservation in the Gulf of Mexico: th...
#
#                                              Google link Taxonomy Systematic  \
# 278    https://scholar.google.com/scholar?&q=A+histor...      NaN        NaN
# 780    https://scholar.google.com/scholar?&q=Aberrant...      NaN        NaN
# 781    https://scholar.google.com/scholar?&q=Aberrant...      NaN        NaN
# 1558   https://scholar.google.com/scholar?&q=Characte...      NaN        NaN
# 3169   https://scholar.google.com/scholar?&q=Direct+a...      NaN        NaN
# 3241   https://scholar.google.com/scholar?&q=Distribu...      NaN        NaN
# 3319   https://scholar.google.com/scholar?&q=Diversit...      NaN        NaN
# 3635   https://scholar.google.com/scholar?&q=Evolutio...      NaN        NaN
# 3682   https://scholar.google.com/scholar?&q=Evolutio...      NaN        NaN
# 3909   https://scholar.google.com/scholar?&q=Expressi...      NaN        NaN
# 4035   https://scholar.google.com/scholar?&q=First+Re...      NaN        NaN
# 4368   https://scholar.google.com/scholar?&q=Genetic+...      NaN        NaN
# 4382   https://scholar.google.com/scholar?&q=Genetic+...      NaN        NaN
# 4383   https://scholar.google.com/scholar?&q=Genetic+...      NaN        NaN
# 4413   https://scholar.google.com/scholar?&q=Genetic+...      NaN        NaN
# 4425   https://scholar.google.com/scholar?&q=Genetic+...      NaN        NaN
# 4669   https://scholar.google.com/scholar?&q=Historic...      NaN        NaN
# 4901   https://scholar.google.com/scholar?&q=Identifi...      NaN        NaN
# 5098   https://scholar.google.com/scholar?&q=In+Vitro...      NaN        NaN
# 5183   https://scholar.google.com/scholar?&q=Infraspe...      NaN        NaN
# 6681   https://scholar.google.com/scholar?&q=Molecula...      NaN        NaN
# 7143   https://scholar.google.com/scholar?&q=Morpholo...      NaN        NaN
# 7258   https://scholar.google.com/scholar?&q=Native+Q...      NaN        NaN
# 7761   https://scholar.google.com/scholar?&q=Paneroa%...      NaN        NaN
# 9442   https://scholar.google.com/scholar?&q=Pilostyl...      NaN        NaN
# 9468   https://scholar.google.com/scholar?&q=Plant+co...      NaN        NaN
# 9603   https://scholar.google.com/scholar?&q=Pollinat...      NaN        NaN
# 9841   https://scholar.google.com/scholar?&q=Quaterna...      NaN        NaN
# 9972   https://scholar.google.com/scholar?&q=Regional...      NaN        NaN
# 10056  https://scholar.google.com/scholar?&q=Report+o...      NaN        NaN
# 10365  https://scholar.google.com/scholar?&q=Sequenci...      NaN        NaN
# 10455  https://scholar.google.com/scholar?&q=Sotoa%2C...      NaN        NaN
# 10838  https://scholar.google.com/scholar?&q=Target+a...      NaN        NaN
# 11159  https://scholar.google.com/scholar?&q=The+comp...      NaN        NaN
# 11206  https://scholar.google.com/scholar?&q=The+ecto...      NaN        NaN
# 11855  https://scholar.google.com/scholar?&q=Unraveli...      NaN        NaN
# 12005  https://scholar.google.com/scholar?&q=Wetland+...      NaN        NaN
#
#       Other related Mexico First gen. Nuclear info Chloroplast info  \
# 278             NaN   Auto        NaN          NaN              NaN
# 780             NaN   Auto        NaN          NaN              NaN
# 781             NaN   Auto        NaN          NaN              NaN
# 1558            NaN   Auto       Auto          NaN              NaN
# 3169            NaN   Auto        NaN          NaN              NaN
# 3241            NaN   Auto        NaN          NaN              NaN
# 3319            NaN   Auto        NaN          NaN              NaN
# 3635            NaN   Auto        NaN          NaN              NaN
# 3682            NaN   Auto        NaN          NaN              NaN
# 3909            NaN   Auto        NaN          NaN              NaN
# 4035            NaN   Auto        NaN          NaN              NaN
# 4368            NaN   Auto        NaN          NaN              NaN
# 4382            NaN   Auto        NaN          NaN              NaN
# 4383            NaN   Auto        NaN          NaN              NaN
# 4413            NaN   Auto        NaN          NaN              NaN
# 4425            NaN   Auto        NaN          NaN              NaN
# 4669           Auto   Auto        NaN          NaN              NaN
# 4901            NaN   Auto        NaN          NaN              NaN
# 5098            NaN   Auto        NaN          NaN              NaN
# 5183            NaN   Auto        NaN          NaN              NaN
# 6681            NaN   Auto        NaN          NaN              NaN
# 7143            NaN   Auto        NaN          NaN              NaN
# 7258            NaN   Auto        NaN          NaN              NaN
# 7761            NaN   Auto        NaN          NaN              NaN
# 9442            NaN   Auto        NaN          NaN              NaN
# 9468           Auto   Auto        NaN          NaN              NaN
# 9603            NaN   Auto        NaN          NaN              NaN
# 9841            NaN   Auto        NaN          NaN              NaN
# 9972            NaN   Auto        NaN          NaN              NaN
# 10056           NaN   Auto        NaN          NaN              NaN
# 10365           NaN   Auto        NaN          NaN              NaN
# 10455           NaN   Auto        NaN          NaN              NaN
# 10838           NaN   Auto        NaN          NaN              NaN
# 11159           NaN   Auto        NaN          NaN              NaN
# 11206           NaN   Auto        NaN          NaN              NaN
# 11855           NaN   Auto        NaN          NaN              NaN
# 12005           NaN   Auto        NaN          NaN              NaN
#
#       Morphology Maximum likelihood Parsimony Third gen. Bayesian Second gen.  \
# 278          NaN                NaN       NaN        NaN      NaN         NaN
# 780          NaN                NaN       NaN        NaN      NaN         NaN
# 781          NaN                NaN       NaN        NaN      NaN         NaN
# 1558         NaN                NaN       NaN        NaN      NaN         NaN
# 3169         NaN                NaN       NaN        NaN      NaN         NaN
# 3241        Auto                NaN       NaN        NaN      NaN         NaN
# 3319         NaN                NaN       NaN        NaN      NaN         NaN
# 3635         NaN                NaN       NaN        NaN      NaN         NaN
# 3682         NaN                NaN       NaN        NaN      NaN         NaN
# 3909         NaN                NaN       NaN        NaN      NaN         NaN
# 4035         NaN                NaN       NaN        NaN      NaN         NaN
# 4368         NaN                NaN       NaN        NaN      NaN         NaN
# 4382         NaN                NaN       NaN        NaN      NaN         NaN
# 4383         NaN                NaN       NaN        NaN      NaN         NaN
# 4413         NaN                NaN       NaN        NaN      NaN         NaN
# 4425         NaN                NaN       NaN        NaN      NaN         NaN
# 4669         NaN                NaN       NaN        NaN      NaN         NaN
# 4901         NaN                NaN       NaN        NaN      NaN         NaN
# 5098         NaN                NaN       NaN        NaN      NaN         NaN
# 5183         NaN                NaN       NaN        NaN      NaN         NaN
# 6681         NaN                NaN       NaN        NaN      NaN         NaN
# 7143        Auto                NaN       NaN        NaN      NaN         NaN
# 7258         NaN                NaN       NaN        NaN      NaN         NaN
# 7761         NaN                NaN       NaN        NaN      NaN         NaN
# 9442         NaN                NaN       NaN        NaN      NaN         NaN
# 9468         NaN                NaN       NaN        NaN      NaN         NaN
# 9603         NaN                NaN       NaN        NaN      NaN         NaN
# 9841         NaN                NaN       NaN        NaN      NaN         NaN
# 9972         NaN                NaN       NaN        NaN      NaN         NaN
# 10056        NaN                NaN       NaN        NaN      NaN         NaN
# 10365        NaN                NaN       NaN        NaN      NaN         NaN
# 10455        NaN                NaN       NaN        NaN      NaN         NaN
# 10838        NaN                NaN       NaN        NaN      NaN         NaN
# 11159        NaN                NaN       NaN        NaN      NaN         NaN
# 11206        NaN                NaN       NaN        NaN      NaN         NaN
# 11855        NaN                NaN       NaN        NaN      NaN         NaN
# 12005        NaN                NaN       NaN        NaN      NaN         NaN
#
#        MSC
# 278    NaN
# 780    NaN
# 781    NaN
# 1558   NaN
# 3169   NaN
# 3241   NaN
# 3319   NaN
# 3635   NaN
# 3682   NaN
# 3909   NaN
# 4035   NaN
# 4368   NaN
# 4382   NaN
# 4383   NaN
# 4413   NaN
# 4425   NaN
# 4669   NaN
# 4901   NaN
# 5098   NaN
# 5183   NaN
# 6681   NaN
# 7143   NaN
# 7258   NaN
# 7761   NaN
# 9442   NaN
# 9468   NaN
# 9603   NaN
# 9841   NaN
# 9972   NaN
# 10056  NaN
# 10365  NaN
# 10455  NaN
# 10838  NaN
# 11159  NaN
# 11206  NaN
# 11855  NaN
# 12005  NaN

# %%
df_final.to_csv("final_database.csv")

# %%
df_final.shape
# Out:
# (4865, 16)
